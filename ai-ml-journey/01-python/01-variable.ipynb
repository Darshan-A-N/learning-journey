# %% [markdown]
# #  Python Basics - Variables & Data Types
#
# Learning Python fundamentals for AI/ML journey.

# %%
# Cell 2 (Code)
# Variables and Data Types
name = "Darshan A N"
age = 20
cgpa = 8.5
is_student = True

print(f"Name: {name}")
print(f"Age: {age}")
print(f"CGPA: {cgpa}")
# Out:
# Name: Darshan A N
# Age: 20
# CGPA: 8.5

# %% [markdown]
# ## Lists
# Ordered collection of items.

# %%
# Cell 4 (Code)
subjects = ["Math", "Physics", "Python", "Electronics"]
subjects.append("AI/ML")
print(f"Subjects: {subjects}")
print(f"First subject: {subjects[0]}")
# Out:
# Subjects: ['Math', 'Physics', 'Python', 'Electronics', 'AI/ML']
# First subject: Math
